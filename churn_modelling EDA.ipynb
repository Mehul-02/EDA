# %%
import numpy as np
import pandas as pd
import matplotlib as plt
import matplotlib.pyplot as plt
import seaborn as sns

# %%
df=pd.read_csv('https://raw.githubusercontent.com/Jalpa-08/Exploratory-Data-Analysis/main/Churn%20Modeling%20_EDA/Churn_Modelling.csv')

# %%
df.head()
# Out:
#    RowNumber  CustomerId   Surname  CreditScore Geography  Gender  Age  \
# 0          1    15634602  Hargrave          619    France  Female   42
# 1          2    15647311      Hill          608     Spain  Female   41
# 2          3    15619304      Onio          502    France  Female   42
# 3          4    15701354      Boni          699    France  Female   39
# 4          5    15737888  Mitchell          850     Spain  Female   43
#
#    Tenure    Balance  NumOfProducts  HasCrCard  IsActiveMember  \
# 0       2       0.00              1          1               1
# 1       1   83807.86              1          0               1
# 2       8  159660.80              3          1               0
# 3       1       0.00              2          0               0
# 4       2  125510.82              1          1               1
#
#    EstimatedSalary  Exited
# 0        101348.88       1
# 1        112542.58       0
# 2        113931.57       1
# 3         93826.63       0
# ...

# %%
df.shape
# Out:
# (10000, 14)

# %%
df.isnull().sum()
# Out:
# RowNumber          0
# CustomerId         0
# Surname            0
# CreditScore        0
# Geography          0
# Gender             0
# Age                0
# Tenure             0
# Balance            0
# NumOfProducts      0
# HasCrCard          0
# IsActiveMember     0
# EstimatedSalary    0
# Exited             0
# dtype: int64

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 10000 entries, 0 to 9999
# Data columns (total 14 columns):
#  #   Column           Non-Null Count  Dtype
# ---  ------           --------------  -----
#  0   RowNumber        10000 non-null  int64
#  1   CustomerId       10000 non-null  int64
#  2   Surname          10000 non-null  object
#  3   CreditScore      10000 non-null  int64
#  4   Geography        10000 non-null  object
#  5   Gender           10000 non-null  object
#  6   Age              10000 non-null  int64
#  7   Tenure           10000 non-null  int64
#  8   Balance          10000 non-null  float64
#  9   NumOfProducts    10000 non-null  int64
#  10  HasCrCard        10000 non-null  int64
#  11  IsActiveMember   10000 non-null  int64
#  12  EstimatedSalary  10000 non-null  float64
#  13  Exited           10000 non-null  int64
# dtypes: float64(2), int64(9), object(3)
# memory usage: 1.1+ MB

# %%
df.Geography.unique()
# Out:
# array(['France', 'Spain', 'Germany'], dtype=object)

# %%
df.Gender.unique()
# Out:
# array(['Female', 'Male'], dtype=object)

# %%
df.Gender.value_counts()
# Out:
# Male      5457
# Female    4543
# Name: Gender, dtype: int64

# %%
plt.figure(figsize=(10,6))
sns.countplot(x='Gender', data=df,palette='rainbow')
# Out:
# <AxesSubplot:xlabel='Gender', ylabel='count'>

# %%
print(df.max())
# Out:
# RowNumber              10000
# CustomerId          15815690
# Surname               Zuyeva
# CreditScore              850
# Geography              Spain
# Gender                  Male
# Age                       92
# Tenure                    10
# Balance            250898.09
# NumOfProducts              4
# HasCrCard                  1
# IsActiveMember             1
# EstimatedSalary    199992.48
# Exited                     1
# dtype: object

# %%
print(df[df.Age == df.Age.max()])
# Out:
#       RowNumber  CustomerId Surname  CreditScore Geography Gender  Age  \
# 6443       6444    15764927  Rogova          753    France   Male   92
# 6759       6760    15660878   T'ien          705    France   Male   92
#
#       Tenure    Balance  NumOfProducts  HasCrCard  IsActiveMember  \
# 6443       3  121513.31              1          0               1
# 6759       1  126076.24              2          1               1
#
#       EstimatedSalary  Exited
# 6443        195563.99       0
# 6759         34436.83       0

# %%
#max age (male and female)
#min age(male and female)
#max balance

# %%
maxValues=df['Balance'].max()
print(maxValues)
# Out:
# 250898.09

# %%
minValues=df['Balance'].min()
print(minValues)
# Out:
# 0.0

# %%
print(df[df['Gender']=='Female']['Age'].max())
# Out:
# 85

# %%
print(df[df['Gender']=='Male']['Age'].max())
# Out:
# 92

# %%
plt.figure(figsize=(10,6))
sns.countplot(x='Geography',hue= 'Gender', data=df,palette='RdBu_r', alpha=0.8)
# Out:
# <AxesSubplot:xlabel='Geography', ylabel='count'>

# %%
plt.figure(figsize=(10,6))
sns.countplot(x='Gender',hue= 'Exited', data=df,palette='RdBu_r', alpha=0.8)
# Out:
# <AxesSubplot:xlabel='Gender', ylabel='count'>

# %%
plt.figure(figsize=(10,6))
sns.countplot(x='IsActiveMember',hue= 'Exited', data=df,palette='RdBu_r', alpha=1.0)
# Out:
# <AxesSubplot:xlabel='IsActiveMember', ylabel='count'>

# %%
plt.figure(figsize=(10,6))
sns.countplot(x='Geography',hue= 'Exited', data=df,palette='RdBu_r', alpha=1.0)
# Out:
# <AxesSubplot:xlabel='Geography', ylabel='count'>

# %%
fig, arr = plt.subplots(3, 2, figsize=(20,12), dpi =300)
sns.boxplot(y='CreditScore', x='Exited',data=df,ax=arr[0][0])
sns.boxplot(y='Age', x='Exited',data=df,ax=arr[0][1])
sns.boxplot(y='Tenure', x='Exited',data=df,ax=arr[1][0])
sns.boxplot(y='Balance', x='Exited',data=df,ax=arr[1][1])
sns.boxplot(y='NumOfProducts', x='Exited',data=df,ax=arr[2][0])
sns.boxplot(y='EstimatedSalary', x='Exited',data=df,ax=arr[2][1])
# Out:
# <AxesSubplot:xlabel='Exited', ylabel='EstimatedSalary'>

# %%
 #one hot encoding create dummy variable
geography=pd.get_dummies(df['Geography'],drop_first=True)
gender=pd.get_dummies(df['Gender'],drop_first=True)

# %%
df.drop(['Geography','Gender'],axis=1,inplace=True)

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 10000 entries, 0 to 9999
# Data columns (total 12 columns):
#  #   Column           Non-Null Count  Dtype
# ---  ------           --------------  -----
#  0   RowNumber        10000 non-null  int64
#  1   CustomerId       10000 non-null  int64
#  2   Surname          10000 non-null  object
#  3   CreditScore      10000 non-null  int64
#  4   Age              10000 non-null  int64
#  5   Tenure           10000 non-null  int64
#  6   Balance          10000 non-null  float64
#  7   NumOfProducts    10000 non-null  int64
#  8   HasCrCard        10000 non-null  int64
#  9   IsActiveMember   10000 non-null  int64
#  10  EstimatedSalary  10000 non-null  float64
#  11  Exited           10000 non-null  int64
# dtypes: float64(2), int64(9), object(1)
# memory usage: 937.6+ KB

# %%
#concatenate the data frame 
df=pd.concat([df,geography,gender],axis=1)

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 10000 entries, 0 to 9999
# Data columns (total 15 columns):
#  #   Column           Non-Null Count  Dtype
# ---  ------           --------------  -----
#  0   RowNumber        10000 non-null  int64
#  1   CustomerId       10000 non-null  int64
#  2   Surname          10000 non-null  object
#  3   CreditScore      10000 non-null  int64
#  4   Age              10000 non-null  int64
#  5   Tenure           10000 non-null  int64
#  6   Balance          10000 non-null  float64
#  7   NumOfProducts    10000 non-null  int64
#  8   HasCrCard        10000 non-null  int64
#  9   IsActiveMember   10000 non-null  int64
#  10  EstimatedSalary  10000 non-null  float64
#  11  Exited           10000 non-null  int64
#  12  Germany          10000 non-null  uint8
#  13  Spain            10000 non-null  uint8
#  14  Male             10000 non-null  uint8
# dtypes: float64(2), int64(9), object(1), uint8(3)
# memory usage: 966.9+ KB
